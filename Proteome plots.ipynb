# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns
sns.set()

# %%
# В R был выполнен следующий код:
# HSP <- filter(The_Proteome, str_detect(The_Proteome$Interpro, "HSP")) %>% 
# unite(Description, Description, Good_p_value, remove = FALSE)
# write.csv(HSP, file = "HSP.csv")

# Здесь я делаю графики для 12 выделенных функций + криптогенов и общий график со средними fold chsnge всех функций

# увы, почти во всех случаях есть как положительные, так и отрицательные изменения белков

# %%
df = pd.read_csv("HSP.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('Heat Shock Proteins', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':14})
    
plt.savefig('HSP.png')

# %%
df = pd.read_csv("transporter.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14,22), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('Transporter Proteins', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':10})
    
plt.savefig('transporter.png')

# %%
df = pd.read_csv("protease.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('Proteases', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':12})
    
plt.savefig('Proteases.png')

# %%
df = pd.read_csv("apoptosis.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(17,4), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.title('Apoptosis', fontdict={'size':20})

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':16})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':16})
    
plt.savefig('apoptosis.png')

# %%
df = pd.read_csv("Transcription_factor.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14,14), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('Transcription factors', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':12})
    
plt.savefig('Transcription_factor.png')

# %%
df = pd.read_csv("Ubiquitin.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14,25), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('Ubiquitin', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':10})
    
plt.savefig('Ubiquitin.png')

# %%
df = pd.read_csv("DNA_repair.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14,4), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':14})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':12})

plt.title('DNA repair', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':12})
    
plt.savefig('DNA_repair.png')

# %%
df = pd.read_csv("Ribosomal.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14,40), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('Ribosomal proteins', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':10})
    
plt.savefig('Ribosomal.png')

# %%
df = pd.read_csv("Actin.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14,12), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('Actin', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':10})
    
plt.savefig('Actin.png')

# %%
df = pd.read_csv("Protein_kinase.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14,28), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('Protein kinases', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':10})
    
plt.savefig('Protein_kinase.png')

# %%
df = pd.read_csv("NADH_dehydrogenase.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14, 8), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('NADH dehydrogenase', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':10})
    
plt.savefig('NADH_dehydrogenase.png')

# %%
df = pd.read_csv("All.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14, 50), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('Все, что было выше, на одном графике', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':12})
    
plt.savefig('All.png')

# %%
# Среднее значение всех белков для каждой из выделенных функций

df = pd.read_csv("mean_all.csv")

x = df.loc[:, ['mean']]
df['mean_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['mean_z']]
df.sort_values('mean_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14, 6), dpi= 80)
plt.hlines(y=df.func, xmin=0, xmax=df.mean_z)

plt.xlabel('Functions', fontdict={'size':18})
plt.ylabel('Mean log2 Fold Change of proteins', fontdict={'size':18})

plt.title('Mean of some proteins by their function', fontdict={'size':22})

for x, y, tex in zip(df.mean_z, df.func, df.mean_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':12})
    
plt.savefig('Mean_functions.png')

# %%
# Белки из списка криптогенов

df = pd.read_csv("cryptogenes.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14, 14), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and gene', fontdict={'size':18})

plt.title('Cryptogenes. Only with p-value < 0.05', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':12})
    
plt.savefig('cryptogenes.png')

# %%
df = pd.read_csv("antioxidants.csv")

x = df.loc[:, ['coefficients']]
df['coefficients_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['coefficients_z']]
df.sort_values('coefficients_z', inplace=True)
df.reset_index(inplace=True)

plt.figure(figsize=(14, 9), dpi= 80)
plt.hlines(y=df.Description, xmin=0, xmax=df.coefficients_z)

plt.xlabel('log2 fold change normalized', fontdict={'size':18})
plt.ylabel('Transcript and if p value is < 0.05', fontdict={'size':18})

plt.title('Antioxidants', fontdict={'size':20})

for x, y, tex in zip(df.coefficients_z, df.Description, df.coefficients_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':12})
    
plt.savefig('antioxidants.png')
